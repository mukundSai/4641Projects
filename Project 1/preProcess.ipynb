# %%
import pandas as pd
import numpy as np

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from matplotlib import pyplot as plt
import seaborn as sns

import io
from scipy import misc

# %matplotlib inline

# %%
data = pd.read_csv('athlete_events.csv')

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# # This is the part of converting all medals to 1 or 0

# %%
data.loc[data.Medal == 'Gold', 'Medal'] = 1
data.loc[data.Medal == 'Bronze', 'Medal'] = 1
data.loc[data.Medal == 'Silver', 'Medal'] = 1

# %%
data.loc[data.Medal.isnull(), 'Medal'] = 0

# %%
data[data.notnull()].head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event  Medal
# 0       Basketball Men's Basketball      0
# 1      Judo Men's Extra-Lightweight      0
# 2           Football Men's Football      0
# 3       Tug-Of-War Men's Tug-Of-War      1
# 4  Speed Skating Women's 500 metres      0

# %%
data = data.drop(columns=['ID', 'Name', 'Games', 'Year', 'Season', 'NOC', 'City'])

# %%
data.dropna()
# Out:
#        Sex   Age  Height  Weight            Team                 Sport  \
# 0        M  24.0   180.0    80.0           China            Basketball
# 1        M  23.0   170.0    60.0           China                  Judo
# 4        F  21.0   185.0    82.0     Netherlands         Speed Skating
# 5        F  21.0   185.0    82.0     Netherlands         Speed Skating
# 6        F  25.0   185.0    82.0     Netherlands         Speed Skating
# 7        F  25.0   185.0    82.0     Netherlands         Speed Skating
# 8        F  27.0   185.0    82.0     Netherlands         Speed Skating
# 9        F  27.0   185.0    82.0     Netherlands         Speed Skating
# 10       M  31.0   188.0    75.0   United States  Cross Country Skiing
# 11       M  31.0   188.0    75.0   United States  Cross Country Skiing
# 12       M  31.0   188.0    75.0   United States  Cross Country Skiing
# 13       M  31.0   188.0    75.0   United States  Cross Country Skiing
# 14       M  33.0   188.0    75.0   United States  Cross Country Skiing
# 15       M  33.0   188.0    75.0   United States  Cross Country Skiing
# 16       M  33.0   188.0    75.0   United States  Cross Country Skiing
# 17       M  33.0   188.0    75.0   United States  Cross Country Skiing
# 18       M  31.0   183.0    72.0   United States  Cross Country Skiing
# 19       M  31.0   183.0    72.0   United States  Cross Country Skiing
# 20       M  31.0   183.0    72.0   United States  Cross Country Skiing
# 21       M  31.0   183.0    72.0   United States  Cross Country Skiing
# 22       M  33.0   183.0    72.0   United States  Cross Country Skiing
# 23       M  33.0   183.0    72.0   United States  Cross Country Skiing
# 24       M  33.0   183.0    72.0   United States  Cross Country Skiing
# 25       M  33.0   183.0    72.0   United States  Cross Country Skiing
# 28       M  26.0   186.0    96.0         Finland            Ice Hockey
# 30       M  22.0   182.0    76.5         Finland  Cross Country Skiing
# 31       M  31.0   172.0    70.0         Finland             Badminton
# 32       F  30.0   159.0    55.5         Finland               Sailing
# 33       F  34.0   159.0    55.5         Finland               Sailing
# 34       F  32.0   171.0    65.0         Finland              Biathlon
# ...     ..   ...     ...     ...             ...                   ...
# 271085   M  36.0   182.0    82.0          Poland               Fencing
# 271086   M  23.0   177.0    68.0          Poland        Figure Skating
# 271087   M  19.0   189.0    80.0          Poland              Swimming
# 271088   M  19.0   189.0    80.0          Poland              Swimming
# 271089   M  34.0   192.0    95.0          Poland               Sailing
# 271090   M  38.0   192.0    95.0          Poland               Sailing
# 271091   M  32.0   200.0    89.0          Poland            Volleyball
# 271092   M  21.0   182.0    79.0          Poland         Speed Skating
# 271093   M  21.0   182.0    79.0          Poland         Speed Skating
# 271094   M  25.0   182.0    79.0          Poland         Speed Skating
# 271095   M  25.0   182.0    79.0          Poland         Speed Skating
# 271096   M  29.0   182.0    79.0          Poland         Speed Skating
# 271097   M  29.0   182.0    79.0          Poland         Speed Skating
# 271098   M  33.0   182.0    79.0          Poland         Speed Skating
# 271099   F  36.0   171.0    63.0          Greece             Wrestling
# 271101   M  24.0   173.0    68.0  Czechoslovakia               Cycling
# 271102   F  19.0   171.0    64.0          Russia             Athletics
# 271103   F  23.0   171.0    64.0          Russia             Athletics
# 271104   M  22.0   172.0    65.0        Russia-1                  Luge
# 271105   M  23.0   168.0    76.0       Argentina                Hockey
# 271106   M  27.0   168.0    76.0       Argentina                Hockey
# 271107   M  21.0   175.0    75.0   United States              Football
# 271108   M  24.0   183.0    72.0          Russia                Rowing
# 271109   M  28.0   183.0    72.0          Russia                Rowing
# 271110   F  33.0   171.0    69.0         Belarus            Basketball
# 271111   M  29.0   179.0    89.0        Poland-1                  Luge
# 271112   M  27.0   176.0    59.0          Poland           Ski Jumping
# 271113   M  27.0   176.0    59.0          Poland           Ski Jumping
# 271114   M  30.0   185.0    96.0          Poland             Bobsleigh
# 271115   M  34.0   185.0    96.0          Poland             Bobsleigh
#
#                                                     Event  Medal
# 0                             Basketball Men's Basketball      0
# 1                            Judo Men's Extra-Lightweight      0
# 4                        Speed Skating Women's 500 metres      0
# 5                      Speed Skating Women's 1,000 metres      0
# 6                        Speed Skating Women's 500 metres      0
# 7                      Speed Skating Women's 1,000 metres      0
# 8                        Speed Skating Women's 500 metres      0
# 9                      Speed Skating Women's 1,000 metres      0
# 10               Cross Country Skiing Men's 10 kilometres      0
# 11               Cross Country Skiing Men's 50 kilometres      0
# 12      Cross Country Skiing Men's 10/15 kilometres Pu...      0
# 13      Cross Country Skiing Men's 4 x 10 kilometres R...      0
# 14               Cross Country Skiing Men's 10 kilometres      0
# 15               Cross Country Skiing Men's 30 kilometres      0
# 16      Cross Country Skiing Men's 10/15 kilometres Pu...      0
# 17      Cross Country Skiing Men's 4 x 10 kilometres R...      0
# 18               Cross Country Skiing Men's 10 kilometres      0
# 19               Cross Country Skiing Men's 50 kilometres      0
# 20      Cross Country Skiing Men's 10/15 kilometres Pu...      0
# 21      Cross Country Skiing Men's 4 x 10 kilometres R...      0
# 22               Cross Country Skiing Men's 10 kilometres      0
# 23               Cross Country Skiing Men's 30 kilometres      0
# 24      Cross Country Skiing Men's 10/15 kilometres Pu...      0
# 25      Cross Country Skiing Men's 4 x 10 kilometres R...      0
# 28                            Ice Hockey Men's Ice Hockey      0
# 30               Cross Country Skiing Men's 30 kilometres      0
# 31                                Badminton Men's Singles      0
# 32                             Sailing Women's Windsurfer      0
# 33                             Sailing Women's Windsurfer      0
# 34                 Biathlon Women's 7.5 kilometres Sprint      0
# ...                                                   ...    ...
# 271085                           Fencing Men's epee, Team      0
# 271086                   Figure Skating Mixed Ice Dancing      0
# 271087                Swimming Men's 100 metres Butterfly      0
# 271088                Swimming Men's 200 metres Butterfly      0
# 271089                  Sailing Men's Two Person Keelboat      0
# 271090                  Sailing Men's Two Person Keelboat      0
# 271091                        Volleyball Men's Volleyball      0
# 271092                   Speed Skating Men's 1,500 metres      0
# 271093                   Speed Skating Men's 5,000 metres      0
# 271094                   Speed Skating Men's 1,500 metres      0
# 271095                   Speed Skating Men's 5,000 metres      0
# 271096                   Speed Skating Men's 5,000 metres      0
# 271097                  Speed Skating Men's 10,000 metres      0
# 271098                   Speed Skating Men's 5,000 metres      0
# 271099          Wrestling Women's Middleweight, Freestyle      0
# 271101           Cycling Men's Team Pursuit, 4,000 metres      0
# 271102             Athletics Women's 4 x 400 metres Relay      1
# 271103             Athletics Women's 4 x 400 metres Relay      1
# 271104                         Luge Mixed (Men)'s Doubles      0
# 271105                                Hockey Men's Hockey      0
# 271106                                Hockey Men's Hockey      0
# 271107                            Football Men's Football      0
# 271108             Rowing Men's Lightweight Coxless Fours      0
# 271109             Rowing Men's Lightweight Coxless Fours      0
# 271110                      Basketball Women's Basketball      0
# 271111                         Luge Mixed (Men)'s Doubles      0
# 271112           Ski Jumping Men's Large Hill, Individual      0
# 271113                 Ski Jumping Men's Large Hill, Team      0
# 271114                               Bobsleigh Men's Four      0
# 271115                               Bobsleigh Men's Four      0
#
# [206165 rows x 8 columns]

# %%
print(data[data.Medal == 1].count())
# Out:
# Sex       39783
# Age       39051
# Height    31072
# Weight    30456
# Team      39783
# Sport     39783
# Event     39783
# Medal     39783
# dtype: int64

# %%
data = data[data.Weight.notnull()]
data = data[data.Height.notnull()]
data = data[data.Age.notnull()]

# %%
print(data[data.Medal == 0].count())
# Out:
# Sex       175984
# Age       175984
# Height    175984
# Weight    175984
# Team      175984
# Sport     175984
# Event     175984
# Medal     175984
# dtype: int64

# %%
dataPositive = data[data.Medal == 1]
dataNegative = data[data.Medal == 0]

# %%
dataNegative = dataNegative.sample(n=30181)

# %%
print(dataNegative.count())
# Out:
# Sex       30181
# Age       30181
# Height    30181
# Weight    30181
# Team      30181
# Sport     30181
# Event     30181
# Medal     30181
# dtype: int64

# %%
finalData = pd.concat([dataPositive, dataNegative], ignore_index=True)

# %%
print(finalData[finalData.Medal==0].count())
# Out:
# Sex       30181
# Age       30181
# Height    30181
# Weight    30181
# Team      30181
# Sport     30181
# Event     30181
# Medal     30181
# dtype: int64

# %%
finalData.head()
# Out:
#        Sex   Age  Height  Weight  Team  Sport  Event  Medal
# 6948     1  19.0   176.0    76.0   143      3     41      1
# 52924    0  19.0   169.0    58.0    27      0      7      0
# 48305    1  22.0   175.0    69.0   162     22    278      0
# 1979     1  28.0   188.0    86.0   102     25    300      1
# 5199     0  24.0   159.0    42.0   135      3     88      1

# %%
finalData = finalData.sample(frac=1)

# %%
export_csv = finalData.to_csv (r'finalData.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
from sklearn import preprocessing


for column in finalData.columns:
    if finalData[column].dtype == type(object):
        le = preprocessing.LabelEncoder()
        finalData[column] = le.fit_transform(finalData[column])

# %% [markdown]
# # Data has been processed and now gonna try decision tree

# %%
train, test = train_test_split(finalData, test_size = 0.2)

# %%
c = DecisionTreeClassifier(min_samples_split = 15)
features = ["Sex", "Age", "Height", "Weight", "Team", "Sport", "Event"]

# %%
X_train = train[features]
y_train = train['Medal']

X_test = test[features]
y_test = test["Medal"]

# %%
dt = c.fit(X_train, y_train)

# %%
y_pred = c.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, y_pred) *100
print(round(score,1))
# Out:
# 70.6
